# %% [markdown]
# <a href="https://colab.research.google.com/github/JCSR2022/2024-1/blob/main/inmuebles_cdmx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyecto practico Proceso ETL usando Pandas
#
#
# Fuimos contratados como científicos de datos por una empresa inmobiliaria para apoyar al equipo de Aprendizaje Automático y Desarrollo. Contamos con un tablero en Trello con las tareas del proyecto y una base de datos para su desarrollo.
#
# https://trello.com/b/LLvoL2ZH/pandas101
#
# Base de datos:
# https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv

# %% [markdown]
# ## Importar la base de datos
#
#
# Se utilizara pandas para importar y analizar los datos

# %%
import pandas as pd
file_address = "https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv"
df = pd.read_csv(file_address)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 1 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto  25121 non-null  object
# dtypes: object(1)
# memory usage: 196.4+ KB

# %% [markdown]
# ### Identificacion de problemas en importacion de datos
#
# El separador para el archivo .csv es ";" en vez de "," se debe ajustar la importacion.
#
# notas sobre el principales ajustes y parámetros útiles de pd.read_csv() en pandas 👇
#
#
# | Parámetro                          | Descripción                                                                       | Ejemplo                                 |
# | ---------------------------------- | --------------------------------------------------------------------------------- | --------------------------------------- |
# | **`sep`**                          | Define el separador entre columnas.                                               | `sep=";"`, `sep="\t"` (tabulador)       |
# | **`encoding`**                     | Controla la codificación del archivo (útil para acentos o caracteres especiales). | `"utf-8"`, `"latin-1"`, `"ISO-8859-1"`  |
# | **`header`**                       | Indica si la primera fila es el encabezado o no.                                  | `header=0` (por defecto), `header=None` |
# | **`names`**                        | Asigna nombres de columnas si el archivo no tiene encabezado.                     | `names=["col1", "col2"]`                |
# | **`usecols`**                      | Carga solo columnas específicas.                                                  | `usecols=["nombre", "edad"]`            |
# | **`index_col`**                    | Usa una columna como índice del DataFrame.                                        | `index_col="id"`                        |
# | **`dtype`**                        | Define el tipo de dato de cada columna.                                           | `dtype={"edad": int, "nombre": str}`    |
# | **`na_values`**                    | Especifica valores que deben considerarse como NaN.                               | `na_values=["NA", "null", "-"]`         |
# | **`skiprows`**                     | Salta un número de filas al inicio o una lista específica.                        | `skiprows=2` o `skiprows=[0,1,3]`       |
# | **`nrows`**                        | Lee solo un número limitado de filas.                                             | `nrows=100`                             |
# | **`parse_dates`**                  | Convierte columnas a formato de fecha automáticamente.                            | `parse_dates=["fecha"]`                 |
# | **`decimal`**                      | Cambia el símbolo usado para decimales.                                           | `decimal=","`                           |
# | **`quotechar`**                    | Define el carácter usado para encerrar textos.                                    | `quotechar='"'`                         |
# | **`error_bad_lines`** *(obsoleto)* | Ignoraba filas con errores de formato. Ahora usar `on_bad_lines`.                 | `on_bad_lines="skip"`                   |
# | **`on_bad_lines`**                 | Controla qué hacer con líneas mal formadas.                                       | `"error"`, `"skip"`, `"warn"`           |

# %%
import pandas as pd

file_address = "https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv"

df = pd.read_csv(file_address, sep=";" , encoding="utf-8")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# ## Verificar características generales
#
# *   Cantidad de filas y columnas.
# *   columnas de la base de datos.
# *   Explorar y Verificar los tipos de datos.
